# %%
import numpy as num
import pandas as pd
import seaborn as sns
from datetime import date
from matplotlib import pyplot as plt
import os
import urllib
# %matplotlib inline
url = "https://covid19.who.int/WHO-COVID-19-global-data.csv"
file_path = os.path.join("data", "covid")
os.makedirs(file_path, exist_ok=True)
csv_path = os.path.join(file_path, "WHO-COVID19-global-data.csv")
urllib.request.urlretrieve(url, csv_path)
df = pd.read_csv(csv_path)
df
# Out:
#        Date_reported Country_code      Country WHO_region  New_cases  \
# 0         2020-01-03           AF  Afghanistan       EMRO          0
# 1         2020-01-04           AF  Afghanistan       EMRO          0
# 2         2020-01-05           AF  Afghanistan       EMRO          0
# 3         2020-01-06           AF  Afghanistan       EMRO          0
# 4         2020-01-07           AF  Afghanistan       EMRO          0
# ...              ...          ...          ...        ...        ...
# 165184    2021-11-25           ZW     Zimbabwe       AFRO         40
# 165185    2021-11-26           ZW     Zimbabwe       AFRO         27
# 165186    2021-11-27           ZW     Zimbabwe       AFRO         62
# 165187    2021-11-28           ZW     Zimbabwe       AFRO        115
# 165188    2021-11-29           ZW     Zimbabwe       AFRO         40
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 0                      0           0                  0
# 1                      0           0                  0
# 2                      0           0                  0
# 3                      0           0                  0
# 4                      0           0                  0
# ...                  ...         ...                ...
# 165184            133747           0               4703
# 165185            133774           1               4704
# 165186            133836           0               4704
# 165187            133951           1               4705
# 165188            133991           0               4705
#
# [165189 rows x 8 columns]

# %%
gr_df = (df.loc[df['Country'] == 'Greece'])
gr_df
# Out:
#       Date_reported Country_code Country WHO_region  New_cases  \
# 56457    2020-01-03           GR  Greece       EURO          0
# 56458    2020-01-04           GR  Greece       EURO          0
# 56459    2020-01-05           GR  Greece       EURO          0
# 56460    2020-01-06           GR  Greece       EURO          0
# 56461    2020-01-07           GR  Greece       EURO          0
# ...             ...          ...     ...        ...        ...
# 57149    2021-11-25           GR  Greece       EURO       7106
# 57150    2021-11-26           GR  Greece       EURO       6561
# 57151    2021-11-27           GR  Greece       EURO       6602
# 57152    2021-11-28           GR  Greece       EURO       5859
# 57153    2021-11-29           GR  Greece       EURO       3823
#
#        Cumulative_cases  New_deaths  Cumulative_deaths
# 56457                 0           0                  0
# 56458                 0           0                  0
# 56459                 0           0                  0
# 56460                 0           0                  0
# 56461                 0           0                  0
# ...                 ...         ...                ...
# 57149            901661          95              17612
# 57150            908222          81              17693
# 57151            914824          86              17779
# 57152            920683          82              17861
# 57153            924506          98              17959
#
# [697 rows x 8 columns]

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x='Date_reported',y='New_cases',data=gr_df)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.lineplot(x='Date_reported',y='New_deaths',data=gr_df)
plt.show()
